# %% [markdown]
# # Interactions - Lab

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this lab, you'll explore interactions in the Boston Housing data set.

# %% [markdown]
# ## Objectives

# %% [markdown]
# You will be able to:
# - Understand what interactions are
# - Understand how to accommodate for interactions in regression

# %% [markdown]
# ## Build a baseline model

# %% [markdown]
# You'll use a couple of built-in functions, which we imported for you below.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.datasets import load_boston
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Import the Boston data set using `load_boston()`. We won't bother to preprocess the data in this lab. If you still want to build a model in the end, you can do that, but this lab will just focus on finding meaningful insights in interactions and how they can improve $R^2$ values.

# %%
regression = LinearRegression()
boston = load_boston()

# %% [markdown]
# Create a baseline model which includes all the variables in the Boston housing data set to predict the house prices. Then use 10-fold cross-validation and report the mean $R^2$ value as the baseline $R^2$.

# %%
y = pd.DataFrame(boston.target,columns = ["target"])
df = pd.DataFrame(boston.data, columns = boston.feature_names)
all_data = pd.concat([y,df], axis = 1)

# Establishing that we'll use K-fold cross validation
crossvalidation = KFold(n_splits=10, shuffle=True, random_state=1)

# Establishing a baseline score using all variables in our df
baseline = np.mean(cross_val_score(regression, df, y, scoring="r2", cv=crossvalidation))

# %%
baseline
# Out:
# 0.7190106820189477

# %% [markdown]
# ## See how interactions improve your baseline

# %% [markdown]
# Next, create all possible combinations of interactions, loop over them and add them to the baseline model one by one to see how they affect the $R^2$. We'll look at the 3 interactions which have the biggest effect on our $R^2$, so print out the top 3 combinations.
#
# You will create a for loop to loop through all the combinations of 2 predictors. You can use `combinations` from itertools to create a list of all the pairwise combinations. To find more info on how this is done, have a look [here](https://docs.python.org/2/library/itertools.html).

# %%
from itertools import combinations
# Creating a list of combos of x variables
combinations = list(combinations(boston.feature_names, 2))

# %%
interactions = []
data = df.copy()
for combo in combinations:
    # Creating an interaction b/w each combo of 2 variables by multiplying them together
    data["interaction"] = data[combo[0]] * data[combo[1]]
    # Using K-fold cross validation, getting the R2 score for each interaction
    score = np.mean(cross_val_score(regression, data, y, scoring="r2", cv=crossvalidation))
    # Only appending the score if the interaction scored higher than our baseline
    # Aka only looking at scores that improve our model
    if score > baseline: interactions.append((combo[0], combo[1], round(score,3)))

# Sorting our interactions to arrive at the top 3, then printing the top 3
sorted_interactions = sorted(interactions, key=lambda inter: inter[2], reverse=True)
print(sorted_interactions[:3])
# Out:
# [('RM', 'LSTAT', 0.786), ('RM', 'TAX', 0.775), ('RM', 'RAD', 0.768)]

# %% [markdown]
# ## Look at the top 3 interactions: "RM" as a confounding factor

# %% [markdown]
# The top three interactions seem to involve "RM", the number of rooms as a confounding variable for all of them. Let's have a look at interaction plots for all three of them. This exercise will involve:
#
# - splitting the data up in 3 groups: one for houses with a few rooms, one for houses with a "medium" amount of rooms, one for a high amount of rooms.
# - Create a function `build_interaction_rm`. This function takes an argument `varname` (which can be set equal to the column name as a string) and a column `description` (which describes the variable or varname, to be included on the x-axis of the plot). The function outputs a plot that uses "RM" as a confounding factor. Each plot should have three regression lines, one for each level of "RM."

# %% [markdown]
# The data has been split into high, medium and low number of rooms for you.

# %%
rm = np.asarray(df[["RM"]]).reshape(len(df[["RM"]]))

# %%
high_rm = all_data[rm > np.percentile(rm, 67)]
med_rm = all_data[(rm > np.percentile(rm, 33)) & (rm <= np.percentile(rm, 67))]
low_rm = all_data[rm <= np.percentile(rm, 33)]

# %% [markdown]
# Create `build_interaction_rm`.

# %%
def build_interaction_rm(varname, description):
    regression_h = LinearRegression()
    regression_m = LinearRegression()
    regression_l = LinearRegression()
    regression_h.fit(high_rm[varname].values.reshape(-1, 1), high_rm["target"])
    regression_m.fit(med_rm[varname].values.reshape(-1, 1), med_rm["target"])
    regression_l.fit(low_rm[varname].values.reshape(-1, 1), low_rm["target"])

    # Make predictions using the testing set
    pred_high = regression_h.predict(high_rm[varname].values.reshape(-1, 1))
    pred_med = regression_m.predict(med_rm[varname].values.reshape(-1, 1))
    pred_low = regression_l.predict(low_rm[varname].values.reshape(-1, 1))

    # The coefficients
    print(regression_h.coef_)
    print(regression_m.coef_)
    print(regression_l.coef_)

    # Plot outputs
    plt.figure(figsize=(12,7))
    plt.scatter(high_rm[varname], high_rm["target"],  color='blue', alpha = 0.3, label = "most rooms")
    plt.scatter(med_rm[varname], med_rm["target"],  color='red', alpha = 0.3, label = "medium rooms")
    plt.scatter(low_rm[varname], low_rm["target"],  color='orange', alpha = 0.3, label = "fewest rooms")

    plt.plot(low_rm[varname], pred_low,  color='orange', linewidth=2)
    plt.plot(med_rm[varname], pred_med,  color='red', linewidth=2)
    plt.plot(high_rm[varname], pred_high,  color='blue', linewidth=2)
    plt.ylabel("house value")
    plt.xlabel(description)
    plt.legend()

# %% [markdown]
# Next, use build_interaction_rm with the three variables that came out with the highest effect on $R^2$

# %%
build_interaction_rm("LSTAT", "% of lower status")
# Out:
# [-1.46614438]
# [-0.67588205]
# [-0.51981339]

# %%
build_interaction_rm("RAD","highway accessibility index")
# Out:
# [-0.66803793]
# [-0.24276834]
# [-0.17393132]

# %%
build_interaction_rm("TAX", "average tax rate")
# Out:
# [-0.03708037]
# [-0.01431143]
# [-0.01166035]

# %% [markdown]
# ## Build a final model including all three interactions at once

# %% [markdown]
# Use 10-fold cross validation.

# %%
# code here

# %%
# code here

# %% [markdown]
# Our $R^2$ has increased considerably! Let's have a look in statsmodels to see if all these interactions are significant.

# %%
# code here

# %% [markdown]
# What is your conclusion here?

# %%
# formulate your conclusion

# %% [markdown]
# ## Summary

# %% [markdown]
# You should now understand how to include interaction effects in your model! As you can see, interactions can have a strong impact on linear regression models, and they should always be considered when you are constructing your models.
